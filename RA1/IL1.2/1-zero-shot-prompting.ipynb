# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/main/RA1/IL1.2/1-zero-shot-prompting.ipynb)

# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 29.1 MB/s eta 0:00:00

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY", "LLM_BASE_URL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.groq.com/openai/v1")
    # Forzamos el modelo explícitamente para evitar que un Secret viejo lo pise
    os.environ["LLM_MODEL"] = "openai/gpt-oss-20b"
    os.environ["LLM_MODEL_SMALL"] = "openai/gpt-oss-20b"
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."

    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"

    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto.

Tarea: Analiza el sentimiento del siguiente texto sobre un producto.

Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]

Texto a analizar: "{texto}"""

    print("=== COMPARACIÓN DE PROMPTS ===")

    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n" + "-"*60)

    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: **Análisis del texto**
#
# > *“El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.”*
#
# | Aspecto | Observaciones |
# |---------|---------------|
# | **Estructura** | El enunciado está compuesto por dos cláusulas coordinadas con la conjunción adversativa “pero”. La primera presenta ventajas (batería y cámara), la segunda señala una desventaja (precio). |
# | **Tono** | Objetivo y descriptivo. El hablante expresa valoración positiva sobre dos características clave y luego introduce una objeción que suaviza el entusiasmo. |
# | **Sentimiento** | **Balanza**: la valoración general es neutral a ligeramente negativa. Las cualidades (batería “increíble”, cámara “fantástica”) generan una carga positiva, mientras que el “precio muy alto” genera una carga negativa que domina el mensaje. |
# | **Propósito** | Funciona como una breve reseña o recomendación de producto. Se enfatiza la calidad técnica y se reconoce la barrera de precio, lo cual sugiere que el producto puede ser atractivo para quienes valoran la tecnología, pero no para todos los consumidores. |
# | **Puntos clave** | 1. **Batería** – “increíble” → rendimiento superior, mayor autonomía. <br> 2. **Cámara** – “fantástica” → calidad de imagen, posiblemente nuevas funciones. <br> 3. **Precio** – “muy alto” → coste elevado, posible impacto en la decisión de compra. |
# | **Implicaciones** | - El mensaje sugiere que el iPhone sigue siendo un dispositivo premium con prestaciones destacadas. <br> - La mención del precio indica que el público objetivo son usuarios dispuestos a pagar un premium por calidad. <br> - Podría usarse en campañas de marketing para resaltar las fortalezas y justificar el precio (por ejemplo, “inversión en tecnología de vanguardia”). |
#
# **Conclusión**
# El texto comunica una valoración equilibrada: destaca dos ventajas técnicas muy valoradas, pero contrarresta con la crítica al coste elevado. El mensaje es coherente y efectivo para una audiencia que valora la calidad pero también es consciente de su presupuesto.
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto so...
# Respuesta: - Sentimiento general: Neutral
# - Aspectos positivos:
#   - Batería increíble
#   - Cámara fantástica
# - Aspectos negativos:
#   - Precio muy alto
# - Puntuación de confianza: 8
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")

    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]

    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.

Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""

    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
#
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
#
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")

    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.

Tarea: Crear un post para LinkedIn sobre el tema dado.

Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement

Tema: "Importancia del aprendizaje continuo en tecnología"

Post para LinkedIn:"""

    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)

        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')

        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# En el mundo tecnológico, la velocidad del cambio es la única constante. Cada año surgen nuevas herramientas, frameworks y metodologías que redefinen cómo construimos, gestionamos y protegemos la información. Adoptar una mentalidad de aprendizaje continuo no solo mejora nuestras habilidades técnicas, sino que también potencia la creatividad, la resiliencia y la capacidad de liderar equipos multidisciplinarios.
#
# El reto no es solo aprender, sino integrar ese conocimiento en procesos reales, compartiendo insights con colegas y contribuyendo a comunidades. La formación continua es la inversión más segura en tu carrera y en la competitividad de tu organización.
#
# ¿Qué estrategias utilizas para mantenerte actualizado en este entorno dinámico?
# #AprendizajeContinuo #Tecnología
# ----------------------------------------
#
# Análisis:
# • Palabras: 107 (límite: 150)
# • Hashtags: 2
# • Preguntas: 1
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")

    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron
    3.2% tras el anuncio."""

    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.

Extrae la siguiente información del texto dado:

Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}

Texto: "{texto_noticia}"

JSON:"""

    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)

        # Intentar parsear como JSON para validar formato
        import json
        try:
            data = json.loads(response.content)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
#
# ✓ Formato JSON válido
# ✓ Campos extraídos: 7 elementos

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")

    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"

    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }

    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"

        print(f"\n{rol.upper()}:")
        print("-" * 30)

        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")

    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# ¡Claro! Mejorar el rendimiento de una aplicación web es clave para ofrecer una experiencia de usuario satisfactoria y también para reducir costos de hosting y mejorar el SEO. A continuación tienes un ...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# ## 1.  Diagnóstico – El primer paso es saber dónde está el cuello de botella
#
# | Herramienta | Qué mide | Por qué es esencial |
# |-------------|----------|----------------------|
# | **Google Lighthouse**...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# ## Guía técnica de optimización de rendimiento web
# *(para una aplicación web moderna, con front‑end SPA/SSR y back‑end API)*
#
# ---
#
# ### 1️⃣ Auditoría inicial
# | Herramienta | Qué mide | Cómo usar ...
#
# CTO:
# ------------------------------
# ## 1️⃣ Visión estratégica
# 1. **Define el objetivo de rendimiento**
#    - ¿Qué métricas importan? (latencia de respuesta, throughput, CPU/RAM, tiempo de carga de la primera página).
#    - Establece...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")

    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"

    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.

Problema: {problema}

Desarrolla una estrategia siguiendo este proceso paso a paso:

PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app

PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección

PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación

PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición

Desarrolla cada paso con detalle:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)

        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())

        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# ## Estrategia de Marketing Digital para el Lanzamiento de una Nueva App de Fitness
#
# > **Objetivo general**: Generar awareness, captar usuarios activos y convertirlos en suscriptores de pago (o usuarios premium) en un plazo de 6 meses.
#
# ---
#
# ### PASO 1 – Análisis Inicial
#
# | Elemento | Detalle |
# |----------|---------|
# | **Público objetivo** | 1️⃣ **Mujeres 25‑40 años, urbanas, con ingresos medios‑altos**<br>2️⃣ **Hombres 18‑35 años, estudiantes o jóvenes profesionales, interesados en rendimiento y comunidad**<br>3️⃣ **Personas con objetivos específicos: pérdida de grasa, tonificación, preparación para eventos deportivos**<br>**Características comunes**: usan smartphones, siguen influencers de fitness, valoran la personalización y la gamificación, buscan resultados rápidos pero sostenibles. |
# | **Puntos de valor únicos** | 1️⃣ **Entrenamientos adaptados en tiempo real**: la app analiza la respuesta fisiológica (frecuencia cardíaca, ritmo respiratorio) y ajusta la intensidad en segundos.<br>2️⃣ **Gamificación social + retos comunitarios**: tablas de clasificación, badges, misiones diarias que se pueden compartir en redes sociales.<br>3️⃣ **Plan nutricional integrado**: recetas, macros calculados automáticamente según objetivo, con opción de comprar ingredientes directamente. |
#
# ---
#
# ### PASO 2 – Canales de Marketing
#
# | Canal | Por qué es efectivo | Métricas clave a monitorizar |
# |-------|---------------------|------------------------------|
# | **TikTok** | Audiencia joven (18‑30 años) que consume contenido de fitness rápido y visual. La app se beneficia de videos “antes y después”, retos de baile con música de moda y “mini‑tutoriales”. | Alcance, interacciones, CTR a la landing page. |
# | **Instagram (Feed + Reels + IGTV)** | Ideal para storytelling visual, influencers y comunidad. Reels permite contenido corto; IGTV para tutoriales largos. | Engagement rate, saves, shares, leads generados vía “link en bio”. |
# | **YouTube** | Plataforma de búsqueda; permite videos de entrenamientos completos, testimonios y tutoriales de uso de la app. | Views, watch‑time, suscriptores, leads. |
# | **Google Ads (Search + Display)** | Captura intención de búsqueda (ej. “app de entrenamiento personalizado”) y remarketing a visitantes del sitio. | CPC, CPA, conversiones. |
# | **WhatsApp Business / Telegram** | Comunicación directa y automatizada con usuarios. Se usa para envío de rutinas semanales, recordatorios y soporte. | Tasa de apertura, tasa de respuesta, retención. |
#
# > **Justificación**: Los 3 primeros canales (TikTok, Instagram, YouTube) cubren la generación de awareness y comunidad. Google Ads asegura captación basada en intención. WhatsApp/Telegram mejora la retención y el soporte, crucial para la fase de “first‑time experience”.
#
# ---
#
# ### PASO 3 – Estrategia de Contenido
#
# | Canal | Tipos de contenido | Frecuencia | Objetivo de la publicación |
# |-------|--------------------|------------|----------------------------|
# | **TikTok** | • Retos de 30 segundos (ej. “30‑second plank challenge”) <br>• “Behind the scenes” de la app <br>• Mini‑tutoriales de ejercicios | 4–5 videos/semana | Generar viralidad, captar seguidores, dirigir tráfico a la landing. |
# | **Instagram Feed** | • Carouseles de “Tips de entrenamiento” <br>• Historias con encuestas y stickers “¿Listo?” <br>• Fotos de usuarios con su progreso | 3–4 posts/semana + 1–2 historias diarias | Construir comunidad, demostrar resultados reales. |
# | **Instagram Reels** | • Entrenamientos de 60 segundos <br>• Comparaciones “antes vs después” <br>• Q&A con entrenadores | 3–4 reels/semana | Alcance orgánico alto, retención de usuarios. |
# | **IGTV / YouTube** | • Series de 5–10 min sobre “Cómo usar la app” <br>• Entrevistas con nutricionistas <br>• Entrenamientos completos (20–30 min) | 1 video/semana | Educar, aumentar tiempo de visualización. |
# | **Google Search Ads** | • Anuncios de texto con CTA “Descarga gratis” <br>• Extensiones de llamada y sitio | 24/7 (según presupuesto) | Captar usuarios con intención alta. |
# | **Display Ads** | • Banners dinámicos con testimonios <br>• Retargeting a usuarios que visitaron la web | 24/7 | Re‑engagement. |
# | **WhatsApp/Telegram** | • Mensajes de “Rutina de la semana” <br>• Recordatorios de sesión <br>• Chats de soporte con bots | 2–3 mensajes/semana | Retención, reducción de churn. |
#
# > **Calendario editorial**: Se recomienda usar un calendario mensual (Google Calendar o Notion) con asignación de temas por semana (ej. “Semana de fuerza”, “Semana de cardio”, “Semana de nutrición”). Cada pieza debe incluir CTA claros (download, subscribe, share).
#
# ---
#
# ### PASO 4 – Métricas y KPIs
#
# | Métrica | Por qué importa | Herramienta recomendada |
# |---------|-----------------|-------------------------|
# | **Costo por adquisición (CPA)** | Mide la rentabilidad de cada canal de adquisición. | Google Ads, Meta Ads Manager, TikTok Ads Manager |
# | **Tasa de conversión de la landing page** | Indica cuántos visitantes se convierten en usuarios registrados. | Google Optimize, Hotjar |
# | **Retention Rate (día 7 / día 30)** | Refleja la capacidad de la app para mantener usuarios activos. | Firebase Analytics, Mixpanel |
# | **Net Promoter Score (NPS) interno** | Evalúa la satisfacción y probabilidad de recomendación. | SurveyMonkey, Typeform |
# | **Engagement Rate (likes, comentarios, shares)** | Mide el impacto del contenido en redes. | Sprout Social, Hootsuite, Meta Insights |
#
# > **Dashboard**: Se recomienda consolidar todas las métricas en un dashboard en Google Data Studio o Power BI. Cada canal tendrá su propio “slice” con comparativas mensuales.
#
# ---
#
# ## Plan de Acción (Primeros 30 Días)
#
# | Semana | Acción | Responsable | KPI inmediato |
# |--------|--------|-------------|----------------|
# | 1 | Lanzar campaña de teaser en TikTok/IG Reels (30 seg. “¿Listos para cambiar?”) | Social Media Manager | Alcance 100k |
# | 1 | Configurar campañas de Google Search (palabras clave: “app entrenamiento personalizado”) | SEM Specialist | CTR 5% |
# | 2 | Publicar primer vídeo educativo en YouTube (cómo usar la app) | Content Creator | Views 10k |
# | 2 | Enviar primer mensaje de WhatsApp “Tu plan está listo” a usuarios que se registren | Growth Manager | Open Rate 80% |
# | 3 | Iniciar reto de 30 seg. en TikTok con influencer fitness | Influencer Marketing | #Hashtag 50k |
# | 3 | Publicar carrousel “3 beneficios únicos” en IG | Graphic Designer | Engagement 8% |
# | 4 | Retargeting Display + WhatsApp “¿Listo para tu primera sesión?” | Digital Marketing | Conversiones 150 |
#
# ---
#
# ## Presupuesto Sugerido (Primer Trimestre)
#
# | Categoría | % del presupuesto | Comentario |
# |-----------|-------------------|------------|
# | **Publicidad pagada (TikTok, IG, YouTube, Google Ads)** | 55% | 70% de este bloque en TikTok & IG Reels (alto ROI). |
# | **Influencers** | 15% | 5‑10 micro‑influencers (10‑50k followers) con código de descuento. |
# | **Producción de contenido** | 10% | Video, fotografía, copywriting. |
# | **Herramientas y software** | 5% | Ads Manager, Hootsuite, Google Analytics, Mixpanel. |
# | **Equipo interno** | 15% | Social Media, Community Manager, Growth Hacker. |
#
# ---
#
# ## Conclusión
#
# Con esta estrategia, la app de fitness no solo genera un flujo constante de nuevos usuarios, sino que también fomenta la comunidad y la retención a largo plazo. La combinación de canales visuales (TikTok, Reels) con plataformas de búsqueda (Google Ads) y soporte directo (WhatsApp/Telegram) asegura cobertura completa del funnel de conversión, desde la conciencia hasta la fidelización.
#
# **Próximo paso**: validar la propuesta con un pequeño test A/B en TikTok y Google Search para calibrar el presupuesto antes del lanzamiento oficial. ¡Éxito con la app!
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")

    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''

    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.

Analiza el siguiente código y proporciona:

1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?

2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento

3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores

4. PUNTUACIÓN DE CALIDAD: [1-10]

Código a analizar:
```python
{codigo_ejemplo}
```

Análisis:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# **1. FUNCIONALIDAD**
# - **Qué hace este código?**
#   La función `process_user_data(users)` recibe una lista de diccionarios (`users`). Cada diccionario debe representar a un usuario con al menos las claves `"name"`, `"email"` y `"age"`. La función itera sobre cada usuario y, si la edad es mayor a 18 años, crea un nuevo diccionario con:
#   - `"name"`: el nombre del usuario convertido a mayúsculas.
#   - `"email"`: el mismo correo electrónico que tenía el usuario original.
#   - `"status"`: la cadena `"adult"`.
#   Todos estos diccionarios se agregan a una lista (`result`) que se devuelve al final.
#
# - **Cuál es su propósito**
#   El objetivo parece ser filtrar usuarios adultos y normalizar su nombre a mayúsculas antes de pasarlos a algún proceso posterior (por ejemplo, generación de reportes, envío de correos, etc.). La función no realiza ninguna acción externa; simplemente devuelve una nueva lista de datos procesados.
#
# ---
#
# **2. PROBLEMAS POTENCIALES**
#
# | Categoría | Detalle | Impacto |
# |-----------|---------|---------|
# | **Errores de lógica** | • No se manejan usuarios con edad igual a 18 (se excluyen).  <br>• Si algún usuario carece de la clave `"age"`, `"name"` o `"email"`, se lanzará un `KeyError`. | Puede provocar fallos inesperados o pérdida de datos. |
# | **Vulnerabilidades de seguridad** | • No hay sanitización ni validación de los campos de entrada. Si el nombre contiene caracteres especiales o se intenta inyectar código (por ejemplo, `<script>`), el nombre se devuelve tal cual. <br>• La función no valida que el correo sea un formato válido, lo que puede generar datos inconsistentes. | Riesgo de inyección de contenido malicioso en la salida, especialmente si la salida se muestra en una interfaz web sin escape. |
# | **Problemas de rendimiento** | • El uso de `list.append` dentro de un bucle es óptimo, pero la función crea un nuevo diccionario para cada usuario adulto, lo que puede ser costoso en memoria si la lista es muy grande. <br>• No se usa comprensión de listas ni generator expressions que podrían ser más legibles y ligeramente más rápidos. | En datasets muy grandes la memoria y el tiempo de ejecución podrían aumentar, aunque el impacto es marginal salvo en producción con cientos de miles de usuarios. |
# | **Manejo de errores** | • No hay captura de excepciones ni validación de tipos. Si `users` no es una lista o contiene elementos que no son diccionarios, la función fallará. | El programa que llame a esta función puede colapsar sin una señal clara de la causa. |
#
# ---
#
# **3. MEJORAS SUGERIDAS**
#
# | Área | Recomendación | Justificación |
# |------|---------------|---------------|
# | **Validación de entrada** | - Verificar que `users` sea iterable y que cada elemento sea un diccionario con las claves requeridas. <br> - Validar que `"age"` sea un número entero (o convertible a int). <br> - Validar que `"email"` siga un patrón básico de correo. | Evita `KeyError`, `TypeError` y datos corruptos. |
# | **Inclusión de edad 18** | - Cambiar la condición a `>= 18` si se considera que 18 años ya es adulto. | Clarifica la regla de negocio. |
# | **Seguridad** | - Escapar los valores de salida o asegurar que la capa que los muestra los escape. <br> - Si se necesita más seguridad, aplicar sanitización (por ejemplo, `bleach.clean`). | Previene XSS y otras inyecciones. |
# | **Código** | - Usar comprensión de listas: <br>```python
# def process_user_data(users):
#     return [
#         {"name": u["name"].upper(), "email": u["email"], "status": "adult"}
#         for u in users
#         if isinstance(u, dict) and u.get("age", 0) >= 18
#     ]
# ``` | Más conciso, evita variables intermedias y es idiomático de Python. |
# | **Manejo de errores** | - Envolver la lógica en un bloque `try/except` y lanzar excepciones descriptivas si la entrada es inválida. | Facilita el debugging y la depuración. |
# | **Documentación** | - Añadir docstring con descripción de parámetros, retorno y ejemplos. | Mejora la mantenibilidad y la comprensión por otros desarrolladores. |
# | **Tipado estático** | - Usar anotaciones de tipo (`List[Dict[str, Any]]`) y, si es posible, `TypedDict` para describir el formato esperado de cada usuario. | Ayuda a IDEs y a herramientas como `mypy`. |
# | **Performance** | - Si la lista es muy grande y la memoria es un problema, devolver un generador (`yield`) en lugar de una lista. | Reduce la huella de memoria. |
# | **Testing** | - Crear pruebas unitarias que cubran: usuarios adultos, menores, datos faltantes, tipos incorrectos, correos inválidos. | Garantiza la robustez del código. |
#
# ---
#
# **4. PUNTUACIÓN DE CALIDAD**
# **7/10**
#
# - **Puntos fuertes**:
#   - Código claro y sencillo.
#   - Uso de `append` es eficiente.
#
# - **Puntos débiles**:
#   - Falta de validación y manejo de errores.
#   - Riesgos de seguridad por falta de sanitización.
#   - No contempla casos de borde (edad 18, datos faltantes).
#   - No documentado ni tipado.
#
# Con las mejoras recomendadas, el código podría alcanzar un nivel de calidad de 9–10, pasando de un simple filtro a una función robusta, segura y mantenible.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")

    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.

    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'

    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users

    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''

    prompt_tests = f"""Eres un QA engineer experto en testing de Python.

Genera tests unitarios completos para la siguiente función usando pytest.

Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado

Función a testear:
```python
{funcion_a_testear}
```

Genera código de test completo y ejecutable:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)

        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")

        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
#
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 0
# • Assertions: 0
# • Tests parametrizados: 0
# • Cobertura estimada: Baja

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")

    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ

# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""

    print(prompt_estudiante)

    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.

Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.

Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción

Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior

Descripción de trabajo:"""

    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)

    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario

ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
